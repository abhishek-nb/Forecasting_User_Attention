# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekKaushikCV/Forecasting_User_Attention/blob/main/Forecasting_User_Attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/MPIIMobileAttention.zip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
 df = pd.read_pickle('/content/Data_P1_RB1.pkl')
 df
# Out:
#         world_frame_number  world_frame_time  ...  astimepassed  astimeremaining
# 0                        0      1.468225e+09  ...             0                0
# 1                        1      1.468225e+09  ...             0                0
# 2                        2      1.468225e+09  ...             0                0
# 3                        3      1.468225e+09  ...             0                0
# 4                        4      1.468225e+09  ...             0                0
# ...                    ...               ...  ...           ...              ...
# 101442              101442      1.468231e+09  ...             0                0
# 101443              101443      1.468231e+09  ...             0                0
# 101444              101444      1.468231e+09  ...             0                0
# 101445              101445      1.468231e+09  ...             0                0
# 101446              101446      1.468231e+09  ...             0                0
#
# ...

# %%
df.head()
# Out:
#    world_frame_number  world_frame_time  ...  astimepassed  astimeremaining
# 0                   0      1.468225e+09  ...             0                0
# 1                   1      1.468225e+09  ...             0                0
# 2                   2      1.468225e+09  ...             0                0
# 3                   3      1.468225e+09  ...             0                0
# 4                   4      1.468225e+09  ...             0                0
#
# [5 rows x 213 columns]

# %%
df["accelerometer_x"].plot()
